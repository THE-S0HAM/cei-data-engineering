# %% [markdown]
# # Part B: Data Analysis Using backpacks.csv Dataset
#
# ## Name: Soham Deshmukh
# This notebook demonstrates basic data preprocessing and analysis operations using the backpacks.csv dataset.

# %%
# !pip install pandas

# %%
import pandas as pd

data = {
    "Name": ["Soham", "Rohit", "Amit"],
    "Age": [21, 22, 20]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age
# 0  Soham   21
# 1  Rohit   22
# 2   Amit   20

# %%
# Program 2: Display First 3 Rows

import pandas as pd

data = {
    "Name": ["A", "B", "C", "D", "E"],
    "Marks": [80, 75, 90, 60, 85]
}

df = pd.DataFrame(data)

print(df.head(3))
# Out:
#   Name  Marks
# 0    A     80
# 1    B     75
# 2    C     90

# %%
# Program 3: Display Last 2 Rows
print(df.tail(2))
# Out:
#   Name  Marks
# 3    D     60
# 4    E     85

# %%
# Program 4: Find Shape of DataFrame
print(df.shape)
# Out:
# (5, 2)

# %%
# Program 5: Display Column Names
print(df.columns)
# Out:
# Index(['Name', 'Marks'], dtype='str')

# %%
# Program 6: Check Data Types
print(df.dtypes)
# Out:
# Name       str
# Marks    int64
# dtype: object

# %%
# Program 7: Select Single Column
print(df["Marks"])
# Out:
# 0    80
# 1    75
# 2    90
# 3    60
# 4    85
# Name: Marks, dtype: int64

# %%
# Program 8: Select Multiple Columns
print(df[["Name", "Marks"]])
# Out:
#   Name  Marks
# 0    A     80
# 1    B     75
# 2    C     90
# 3    D     60
# 4    E     85

# %%
# Program 9: Filter Records with Marks > 80
print(df[df["Marks"] > 80])
# Out:
#   Name  Marks
# 2    C     90
# 4    E     85

# %%
# Program 10: Create Derived Column
df["Grade"] = df["Marks"] / 10

print(df)
# Out:
#   Name  Marks  Grade
# 0    A     80    8.0
# 1    B     75    7.5
# 2    C     90    9.0
# 3    D     60    6.0
# 4    E     85    8.5

# %% [markdown]
# ## Now using dataset

# %%
# Program 1: Load Dataset and Display First 5 Rows

df = pd.read_csv(r"C:\Users\Soham Deshmukh\Desktop\B.Tech\Celebal Internship\cei-data-engineering\WEEK-1\Dataset\backpacks.csv")

print(df.head())
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15         3995.0      58.0  "₹3,995.00"      INR
# 1     4.5             67         2899.0      35.0  "₹2,899.00"      INR
# 2     4.4            226         2999.0      65.0  "₹2,999.00"      INR
# 3     4.4           1052         1675.0      52.0  "₹1,675.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
# 1  http://assets.myntassets.com/assets/images/913...  ...
# ...

# %%
print(df.shape)
# Out:
# (4, 24)

# %%
print(df.columns.tolist())
# Out:
# ['product_id', 'title', 'product_description', 'rating', 'ratings_count', 'initial_price', 'discount', 'final_price', 'currency', 'images', 'delivery_options', 'product_details', 'breadcrumbs', 'product_specifications', 'amount_of_stars', 'what_customers_said', 'seller_name', 'sizes', 'videos', 'seller_information', 'variations', 'best_offer', 'more_offers', 'category']

# %%
print(df.dtypes)
# Out:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price             float64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said       float64
# seller_name               float64
# sizes                         str
# videos                        str
# seller_information        float64
# variations                    str
# best_offer                    str
# more_offers                   str
# category                      str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              4 non-null      int64
#  1   title                   4 non-null      str
#  2   product_description     4 non-null      str
#  3   rating                  4 non-null      float64
#  4   ratings_count           4 non-null      int64
#  5   initial_price           4 non-null      float64
#  6   discount                4 non-null      float64
#  7   final_price             4 non-null      str
#  8   currency                4 non-null      str
#  9   images                  4 non-null      str
#  10  delivery_options        4 non-null      str
#  11  product_details         4 non-null      str
#  12  breadcrumbs             4 non-null      str
#  13  product_specifications  4 non-null      str
#  14  amount_of_stars         4 non-null      str
# ...

# %%
print(df.isnull().sum())
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       4
# seller_name               4
# sizes                     0
# videos                    0
# seller_information        4
# variations                1
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %%
print(df.describe())
# Out:
#          product_id    rating  ratings_count  initial_price   discount  \
# count  4.000000e+00  4.000000       4.000000       4.000000   4.000000
# mean   9.130937e+06  4.275000     340.000000    2892.000000  52.500000
# std    6.658103e+06  0.320156     483.078324     950.297497  12.819256
# min    1.376949e+06  3.800000      15.000000    1675.000000  35.000000
# 25%    6.626811e+06  4.250000      54.000000    2593.000000  47.750000
# 50%    8.756523e+06  4.400000     146.500000    2949.000000  55.000000
# 75%    1.126065e+07  4.425000     432.500000    3248.000000  59.750000
# max    1.763375e+07  4.500000    1052.000000    3995.000000  65.000000
#
#        what_customers_said  seller_name  seller_information
# count                  0.0          0.0                 0.0
# mean                   NaN          NaN                 NaN
# std                    NaN          NaN                 NaN
# min                    NaN          NaN                 NaN
# ...

# %%
print(
    df[
        [
            "title",
            "rating",
            "final_price"
        ]
    ].head()
)
# Out:
#             title  rating  final_price
# 0     Lino Perros     3.8  "₹3,995.00"
# 1  Tommy Hilfiger     4.5  "₹2,899.00"
# 2           Lavie     4.4  "₹2,999.00"
# 3          F Gear     4.4  "₹1,675.00"

# %%
high_rating = df[df["rating"] >= 4.5]

print(high_rating.head())
# Out:
#    product_id           title                product_description  rating  \
# 1     9136281  Tommy Hilfiger  Unisex Navy Blue Striped Backpack     4.5
#
#    ratings_count  initial_price  discount  final_price currency  \
# 1             67         2899.0      35.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# 1  http://assets.myntassets.com/assets/images/913...  ...
#
#                                      amount_of_stars what_customers_said  \
# 1  {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...                 NaN
#
#   seller_name                 sizes                 videos  \
# 1         NaN  [{"size":"Onesize"}]  ["rw-9136281_cae700"]
#
#    seller_information  variations best_offer  \
# 1                 NaN     [{},{}]         {}
#
#                                          more_offers   category
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
#
# [1 rows x 24 columns]

# %%
total_missing = df.isnull().sum().sum()

print(total_missing)
# Out:
# 13

# %%
df["seller_name"] = df["seller_name"].fillna(
    "Unknown Seller"
)

print(df["seller_name"].isnull().sum())
# Out:
# 0

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df = df.drop_duplicates()

print(df.shape)
# Out:
# (4, 24)
